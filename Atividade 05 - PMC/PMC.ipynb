# %% [markdown]
# # TDNN - Atividade 05
#
# Previsão de série temporal financeira.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Os resultados consolidados e os gráficos estão registrados no arquivo `README.md` e em `grafico_eqm_melhores.png` / `grafico_previsoes.png`.
